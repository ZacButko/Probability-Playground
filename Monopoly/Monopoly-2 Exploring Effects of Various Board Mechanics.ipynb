# %%
# Time to clean things up

# %%
# %run /Users/zabutko/Documents/scripts/monopoly_board.py

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# a turn consists of 
# 1) rolling dice
# 2) moving to a space
# 3) check if there are special rules about that space
# 4) special rules cause you to jump to a new space

# %%
gb = GameBoard()
n_rolls = 10000000

# %%
gb.update_play_options(jail = False, chance = False, community_chest = False, jail_doubles = True)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("No special rules")
plt.show()
# Out:
# gojf_cards0
# gojf_count0

# %%
gb.update_play_options(jail = True, chance = False, community_chest = False, jail_doubles = False)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("Jail with no other rules")
plt.show()
# Out:
# gojf_cards0
# gojf_count0

# %%
gb.update_play_options(jail = True, chance = False, community_chest = False, jail_doubles = True, jail_gojf = False)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("Jail with doubles")
plt.show()
# Out:
# gojf_cards0
# gojf_count0

# %%
gb.update_play_options(jail = True, chance = False, community_chest = False, jail_doubles = True, jail_gojf=True)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("Jail with doubles and get out of jail free")
plt.show()
# Out:
# gojf_cards0
# gojf_count0

# %%
gb.update_play_options(jail = False, chance = True, community_chest = False, jail_doubles = True, jail_gojf=True)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("Just Chance")
plt.show()
# Out:
# gojf_cards0
# gojf_count41493

# %%
gb.update_play_options(jail = False, chance = False, community_chest = True, jail_doubles = True)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("Just Community Chest")
plt.show()
# Out:
# gojf_cards0
# gojf_count32096

# %%
gb.update_play_options(jail = True, chance = True, community_chest = True, jail_doubles = True)
histo, edges = gb.walk_piece_get_histo(n_rolls)
plt.figure(figsize=(8,5))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
# plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("All Rules On")
plt.show()
# Out:
# gojf_cards0
# gojf_count73326

# %%
# next let's find average of all ownable properties
total = 0
possible_properties = [1, 3, 5, 6, 8, 9, 11, 12, 13, 14, 15, 16, 18, 19, 21, 23, 24, 25, 26, 27, 28, 29, 31, 32, 34, 35, 37, 39]
for i in possible_properties:
    total += histo[i]

average = total / len(possible_properties)

plt.figure(figsize=(12,8))
plt.bar(edges[:40], histo, color = gb.x_label_colors, edgecolor='black')
plt.plot([0, 39],[average, average], color='red')
plt.xticks(np.arange(40), gb.x_labels, rotation=90)
plt.title("All Rules On\n Median Line Shown for All Own-able Properties")
plt.show()
